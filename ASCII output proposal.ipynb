# %% [markdown]
# ASCII output proposal

# %%
# general
population = 12.34567
food = 12.34567

# distribution
farmer = 0.3
scientist = 0.6
worker = 0.1

# overview screen
overview = """
----------------------------------------------------------
| Overview                                               |
|                                                        |
|                                                        |
|                                                        |
|                                                        |
----------------------------------------------------------
"""

# production screen
production = """
----------------------------------------------------------
| Production                                             |
|                                                        |
|                                                        |
|                                                        |
|                                                        |
----------------------------------------------------------
"""

# upgrades screen
upgrades = """
----------------------------------------------------------
| Upgrades                                               |
|                                                        |
|                                                        |
|                                                        |
|                                                        |
----------------------------------------------------------
"""

# print results for year
run = True
while run:
    page = str(input("please select a page to view. [1= Overview 2= production 3= upgrades q= Quit] Your choice: "))
    if page in ("1","overview","Overview"):
        print (overview)
    elif page in ("2","production","Production"):
        print (production)
    elif page in ("3","upgrades","Upgrades"):
        print (upgrades)
    elif page in ("q","Q","quit","Quit","c","continue"):
        print ("a new year begins...")
        run = False
    else:
        print ("no choice is a good choice")
# Out:
# please select a page to view. [1= Overview 2= production 3= upgrades q= Quit] Your choice: 1
# you choose 1
#
# ----------------------------------------------------------
# | Overview                                               |
# |                                                        |
# |                                                        |
# |                                                        |
# |                                                        |
# ----------------------------------------------------------
#
# please select a page to view. [1= Overview 2= production 3= upgrades q= Quit] Your choice: 2
# you choose 2
#
# ----------------------------------------------------------
# | Production                                             |
# |                                                        |
# |                                                        |
# |                                                        |
# ...
